# %% [markdown]
# <a href="https://colab.research.google.com/github/Koveraaman/DL_CNC_MACHINING_PREDICTION/blob/main/CNC_PREDICTION__DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.37.13-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.38.0,>=1.37.13 (from boto3)
#   Downloading botocore-1.37.13-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3)
#   Downloading s3transfer-0.11.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.13->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.13->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.13->boto3) (1.17.0)
# Downloading boto3-1.37.13-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.6/139.6 kB 4.8 MB/s eta 0:00:00
# Downloading botocore-1.37.13-py3-none-any.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 87.2 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.4-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.37.13 botocore-1.37.13 jmespath-1.0.1 s3transfer-0.11.4

# %%
import boto3

# %%
access_key= "AKIAXKPUZOC2DSUGK46L"
security_key= "er0mgpQSZDAuJIBtctuZXZydmrFVxvAW5eyakYCu"

# %%
aws= boto3.client('s3',
                 aws_access_key_id= access_key,
                 aws_secret_access_key= security_key)

# %%
bucket= aws.list_buckets()
bucket
# Out:
# {'ResponseMetadata': {'RequestId': 'YCRWDQHKNXXX7B58',
#   'HostId': 'lfhU/tWxGiCShzqvrklJs6DVfXzzF/0K464lO6tWpMkNWZcrcSxGQlqQ+jNtux4EUCibBI6PtDk=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'lfhU/tWxGiCShzqvrklJs6DVfXzzF/0K464lO6tWpMkNWZcrcSxGQlqQ+jNtux4EUCibBI6PtDk=',
#    'x-amz-request-id': 'YCRWDQHKNXXX7B58',
#    'date': 'Mon, 17 Mar 2025 10:35:29 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'bucketkr',
#    'CreationDate': datetime.datetime(2025, 2, 5, 9, 14, 34, tzinfo=tzlocal())},
#   {'Name': 'cnckrbucket',
#    'CreationDate': datetime.datetime(2025, 3, 5, 7, 31, tzinfo=tzlocal())}],
#  'Owner': {'DisplayName': 'koveraaman',
#   'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}}

# %%
bucket['Buckets'][1]['Name']
# Out:
# 'cnckrbucket'

# %%
bucket_file= aws.list_objects(Bucket= bucket['Buckets'][1]['Name'])
bucket_file
# Out:
# {'ResponseMetadata': {'RequestId': 'BGT1RP78TKQC3GGK',
#   'HostId': '7GOhMzTIa/mlSxLe8HDT3dlsdW6GDrdyb5Qet0fAI78kyVBpIbXpL/C/JP4uP+K04x/PZTra6oPkewt32atMGS2AWO14dsup',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '7GOhMzTIa/mlSxLe8HDT3dlsdW6GDrdyb5Qet0fAI78kyVBpIbXpL/C/JP4uP+K04x/PZTra6oPkewt32atMGS2AWO14dsup',
#    'x-amz-request-id': 'BGT1RP78TKQC3GGK',
#    'date': 'Mon, 17 Mar 2025 10:35:36 GMT',
#    'x-amz-bucket-region': 'ap-south-1',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 1},
#  'IsTruncated': False,
#  'Marker': '',
#  'Contents': [{'Key': 'experiment_01.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 19, tzinfo=tzlocal()),
#    'ETag': '"ec446ebdb5a8a5080f45ca94584f7bf8"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 467193,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_02.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 28, tzinfo=tzlocal()),
#    'ETag': '"d5eeb79301589e6f7a69755e018e7b68"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 736459,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_03.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 27, tzinfo=tzlocal()),
#    'ETag': '"564d87acb6eeda1db07c984f11ca2443"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 671985,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_04.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 27, tzinfo=tzlocal()),
#    'ETag': '"2002b1d636d3b7d4e2793ab7af7131c7"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 234196,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_05.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 26, tzinfo=tzlocal()),
#    'ETag': '"5d6baa0fbeb6c3f73d65a0f895d70b7a"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 202320,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_06.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 26, tzinfo=tzlocal()),
#    'ETag': '"89454311421fd0de8f763ca6656212a1"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 574296,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_07.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 26, tzinfo=tzlocal()),
#    'ETag': '"bf87dc61fe45c85a6c9cf1cabcb96f8c"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 250860,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_08.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 25, tzinfo=tzlocal()),
#    'ETag': '"3bd7306ea2f8909e404628d07a7e2e62"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 267820,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_09.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 25, tzinfo=tzlocal()),
#    'ETag': '"9d2accc6ea23a8193c43df12a1c2de52"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 328887,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_10.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 25, tzinfo=tzlocal()),
#    'ETag': '"693d3b84ed06e5f22f4b50a191f4060f"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 574595,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_11.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 24, tzinfo=tzlocal()),
#    'ETag': '"e597fe0db6b6229eadaf37aa7a790f77"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 1022545,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_12.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 24, tzinfo=tzlocal()),
#    'ETag': '"c446004a20e1f10364ab3bd176fa957a"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 1004981,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_13.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 23, tzinfo=tzlocal()),
#    'ETag': '"ca36136bf7a5888b7ea4831d426922ca"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 987653,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_14.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 22, tzinfo=tzlocal()),
#    'ETag': '"e42914093170b2a5084cbd092af9d535"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 1030795,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_15.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 22, tzinfo=tzlocal()),
#    'ETag': '"3df79bab51e42b6eb0c5d37b0625a896"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 608883,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_16.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 21, tzinfo=tzlocal()),
#    'ETag': '"8cddf3820708cbfa068e9244e064830e"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 264491,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_17.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 21, tzinfo=tzlocal()),
#    'ETag': '"4970660ce4def219e89b00e8f6d0b6eb"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 948848,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'experiment_18 - experiment_18.csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 20, tzinfo=tzlocal()),
#    'ETag': '"99fbd3a4f9ed1b5721a0623dee0d8e83"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 996059,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}},
#   {'Key': 'train (1).csv',
#    'LastModified': datetime.datetime(2025, 3, 5, 7, 37, 18, tzinfo=tzlocal()),
#    'ETag': '"5616823a4f06c1420a4928a39126e937"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 547,
#    'StorageClass': 'STANDARD',
#    'Owner': {'ID': '91937d965fba5a93ac554c2381340c3c96b82d0703512fb5880a2fc51452841c'}}],
#  'Name': 'cnckrbucket',
#  'Prefix': '',
#  'MaxKeys': 1000,
#  'EncodingType': 'url'}

# %%
aws.download_file('cnckrbucket','experiment_01.csv','experiment_01.csv')

# %%
aws.download_file('cnckrbucket','experiment_02.csv','experiment_02.csv')
aws.download_file('cnckrbucket','experiment_03.csv','experiment_03.csv')
aws.download_file('cnckrbucket','experiment_04.csv','experiment_04.csv')
aws.download_file('cnckrbucket','experiment_05.csv','experiment_05.csv')
aws.download_file('cnckrbucket','experiment_06.csv','experiment_06.csv')
aws.download_file('cnckrbucket','experiment_07.csv','experiment_07.csv')
aws.download_file('cnckrbucket','experiment_08.csv','experiment_08.csv')
aws.download_file('cnckrbucket','experiment_09.csv','experiment_09.csv')
aws.download_file('cnckrbucket','experiment_10.csv','experiment_10.csv')
aws.download_file('cnckrbucket','experiment_11.csv','experiment_11.csv')
aws.download_file('cnckrbucket','experiment_12.csv','experiment_12.csv')
aws.download_file('cnckrbucket','experiment_13.csv','experiment_13.csv')
aws.download_file('cnckrbucket','experiment_14.csv','experiment_14.csv')
aws.download_file('cnckrbucket','experiment_15.csv','experiment_15.csv')
aws.download_file('cnckrbucket','experiment_16.csv','experiment_16.csv')
aws.download_file('cnckrbucket','experiment_17.csv','experiment_17.csv')

# %%
aws.download_file('cnckrbucket','experiment_18 - experiment_18.csv','experiment_18 - experiment_18.csv')
aws.download_file('cnckrbucket','train (1).csv','train (1).csv')

# %%
import os
import glob
import pandas as pd  # Import pandas for reading CSV files

# Get a list of all CSV files matching the pattern
file_list = glob.glob('experiment_*.csv')  # Renamed 'file' to 'file_list' to avoid confusion
print(f"✅ Found {len(file_list)} experiment CSV files:")
for file_path in file_list:  # Iterating through file paths
    print(file_path)  # Print the file path only once

df_list = []

# Loop through each CSV file
for i, file_path in enumerate(file_list, start=1):  # Using 'file_list'
    try:
        # Read the CSV into a pandas DataFrame
        df = pd.read_csv(file_path)
        # Add an experiment number column
        df["No"] = i
        # Append the DataFrame to the list
        df_list.append(df)
    except Exception as e:
        print(f"⚠️ Error reading {file_path}: {e}")

# Check if any DataFrames were loaded and print the shape of the first one if available

if df_list:
    merged_experiments = pd.concat(df_list, ignore_index=True)
    print("✅ Merging completed! Final dataset shape:", merged_experiments.shape)
else:
    print("❌ No valid experiment CSVs found to merge.")

merged_experiments.to_csv("merged_experiments.csv")
# Out:
# ✅ Found 18 experiment CSV files:
# experiment_04.csv
# experiment_05.csv
# experiment_17.csv
# experiment_08.csv
# experiment_16.csv
# experiment_18 - experiment_18.csv
# experiment_06.csv
# experiment_03.csv
# experiment_14.csv
# experiment_13.csv
# experiment_09.csv
# experiment_15.csv
# experiment_01.csv
# experiment_12.csv
# experiment_07.csv
# experiment_11.csv
# experiment_02.csv
# experiment_10.csv
# ✅ Merging completed! Final dataset shape: (25286, 49)

# %%
df= pd.read_csv('merged_experiments.csv')
df
# Out:
#        Unnamed: 0  X1_ActualPosition  X1_ActualVelocity  \
# 0               0              198.0              0.025
# 1               1              198.0              0.000
# 2               2              198.0              0.000
# 3               3              198.0              0.025
# 4               4              198.0             -0.025
# ...           ...                ...                ...
# 25281       25281              151.0              0.025
# 25282       25282              150.0            -11.800
# 25283       25283              149.0            -11.900
# 25284       25284              148.0            -12.100
# 25285       25285              147.0            -11.900
#
#        X1_ActualAcceleration  X1_CommandPosition  X1_CommandVelocity  \
# 0                       6.25               198.0                 0.0
# 1                       0.00               198.0                 0.0
# 2                       0.00               198.0                 0.0
# 3                       6.25               198.0                 0.0
# 4                      -6.25               198.0                 0.0
# ...                      ...                 ...                 ...
# 25281                   6.25               151.0                 0.0
# 25282                  12.50               150.0               -12.0
# 25283                  68.70               149.0               -12.0
# 25284                 -37.50               148.0               -12.0
# 25285                  68.70               146.0               -12.0
#
#        X1_CommandAcceleration  X1_CurrentFeedback  X1_DCBusVoltage  \
# 0                         0.0              -1.420           0.0219
# 1                         0.0              -1.900           0.0206
# 2                         0.0              -2.060           0.0237
# 3                         0.0              -2.220           0.0225
# 4                         0.0               0.499           0.0260
# ...                       ...                 ...              ...
# 25281                     0.0               0.108           0.0215
# 25282                     0.0              -5.450           0.1200
# 25283                     0.0              -5.080           0.0881
# 25284                     0.0              -3.750           0.1030
# 25285                     0.0              -6.840           0.1170
#
#        X1_OutputCurrent  ...  S1_DCBusVoltage  S1_OutputCurrent  \
# 0                 328.0  ...     2.750000e-19             328.0
# 1                 329.0  ...     2.750000e-19             328.0
# 2                 329.0  ...     2.750000e-19             329.0
# 3                 329.0  ...     2.750000e-19             329.0
# 4                 329.0  ...     2.750000e-19             329.0
# ...                 ...  ...              ...               ...
# 25281             324.0  ...     8.850000e-01             321.0
# 25282             324.0  ...     9.630000e-01             321.0
# 25283             324.0  ...     9.780000e-01             320.0
# 25284             324.0  ...     8.320000e-01             321.0
# 25285             324.0  ...     1.010000e+00             321.0
#
#        S1_OutputVoltage  S1_OutputPower  S1_SystemInertia  \
# 0                   0.0   -9.930000e-07              12.0
# 1                   0.0    7.290000e-07              12.0
# 2                   0.0    0.000000e+00              12.0
# 3                   0.0    0.000000e+00              12.0
# 4                   0.0    0.000000e+00              12.0
# ...                 ...             ...               ...
# 25281             120.0    1.700000e-01              12.0
# 25282             120.0    1.840000e-01              12.0
# 25283             118.0    1.890000e-01              12.0
# 25284             120.0    1.600000e-01              12.0
# 25285             118.0    1.960000e-01              12.0
#
#        M1_CURRENT_PROGRAM_NUMBER  M1_sequence_number  M1_CURRENT_FEEDRATE  \
# 0                            1.0                 2.0                 50.0
# 1                            1.0                 0.0                 50.0
# 2                            1.0                 0.0                 50.0
# 3                            1.0                 0.0                 50.0
# 4                            1.0                 0.0                 50.0
# ...                          ...                 ...                  ...
# 25281                        1.0                96.0                 12.0
# 25282                        1.0                96.0                 12.0
# 25283                        1.0                96.0                 12.0
# 25284                        1.0                96.0                 12.0
# 25285                        1.0                96.0                 12.0
#
#        Machining_Process  No
# 0                   Prep   1
# 1                   Prep   1
# 2                   Prep   1
# 3                   Prep   1
# 4                   Prep   1
# ...                  ...  ..
# 25281                End  18
# 25282                End  18
# 25283                End  18
# 25284                End  18
# 25285                End  18
#
# [25286 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25286 entries, 0 to 25285
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 25286 non-null  int64
#  1   X1_ActualPosition          25286 non-null  float64
#  2   X1_ActualVelocity          25286 non-null  float64
#  3   X1_ActualAcceleration      25286 non-null  float64
#  4   X1_CommandPosition         25286 non-null  float64
#  5   X1_CommandVelocity         25286 non-null  float64
#  6   X1_CommandAcceleration     25286 non-null  float64
#  7   X1_CurrentFeedback         25286 non-null  float64
#  8   X1_DCBusVoltage            25286 non-null  float64
#  9   X1_OutputCurrent           25286 non-null  float64
#  10  X1_OutputVoltage           25286 non-null  float64
#  11  X1_OutputPower             25286 non-null  float64
#  12  Y1_ActualPosition          25286 non-null  float64
#  13  Y1_ActualVelocity          25286 non-null  float64
#  14  Y1_ActualAcceleration      25286 non-null  float64
#  15  Y1_CommandPosition         25286 non-null  float64
#  16  Y1_CommandVelocity         25286 non-null  float64
#  17  Y1_CommandAcceleration     25286 non-null  float64
#  18  Y1_CurrentFeedback         25286 non-null  float64
#  19  Y1_DCBusVoltage            25286 non-null  float64
#  20  Y1_OutputCurrent           25286 non-null  float64
#  21  Y1_OutputVoltage           25286 non-null  float64
#  22  Y1_OutputPower             25286 non-null  float64
#  23  Z1_ActualPosition          25286 non-null  float64
#  24  Z1_ActualVelocity          25286 non-null  float64
#  25  Z1_ActualAcceleration      25286 non-null  float64
#  26  Z1_CommandPosition         25286 non-null  float64
#  27  Z1_CommandVelocity         25286 non-null  float64
#  28  Z1_CommandAcceleration     25286 non-null  float64
#  29  Z1_CurrentFeedback         25286 non-null  float64
#  30  Z1_DCBusVoltage            25286 non-null  float64
#  31  Z1_OutputCurrent           25286 non-null  float64
#  32  Z1_OutputVoltage           25286 non-null  float64
#  33  S1_ActualPosition          25286 non-null  float64
#  34  S1_ActualVelocity          25286 non-null  float64
#  35  S1_ActualAcceleration      25286 non-null  float64
#  36  S1_CommandPosition         25286 non-null  float64
#  37  S1_CommandVelocity         25286 non-null  float64
#  38  S1_CommandAcceleration     25286 non-null  float64
#  39  S1_CurrentFeedback         25286 non-null  float64
#  40  S1_DCBusVoltage            25286 non-null  float64
#  41  S1_OutputCurrent           25286 non-null  float64
#  42  S1_OutputVoltage           25286 non-null  float64
#  43  S1_OutputPower             25286 non-null  float64
#  44  S1_SystemInertia           25286 non-null  float64
#  45  M1_CURRENT_PROGRAM_NUMBER  25286 non-null  float64
#  46  M1_sequence_number         25286 non-null  float64
#  47  M1_CURRENT_FEEDRATE        25286 non-null  float64
#  48  Machining_Process          25286 non-null  object
#  49  No                         25286 non-null  int64
# dtypes: float64(47), int64(2), object(1)
# memory usage: 9.6+ MB

# %%
df.drop(columns= ['Unnamed: 0'], inplace= True)

# %%
train= pd.read_csv('train (1).csv')

if "No" not in train.columns:
    raise ValueError("Column 'No' not found in train.csv!")

# Convert 'No' column to integer
train['No'] = train['No'].astype(int)

print("Train data loaded! Shape:", train.shape)
# Out:
# Train data loaded! Shape: (18, 7)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   No                        18 non-null     int64
#  1   material                  18 non-null     object
#  2   feedrate                  18 non-null     int64
#  3   clamp_pressure            18 non-null     float64
#  4   tool_condition            18 non-null     object
#  5   machining_finalized       18 non-null     object
#  6   passed_visual_inspection  14 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.1+ KB

# %%
train.fillna('no', inplace= True)

# %%
# Convert "No" column to int in both datasets
merged_experiments['No'] = merged_experiments['No'].astype(int)
train['No'] = train['No'].astype(int) # Convert 'No' column in train to int

# Merge based on "No" column
final = pd.merge(merged_experiments, train, on='No', how='left')

print("✅ Final merged dataset shape:", final.shape)
# Merge based on "No" column
final = pd.merge(merged_experiments, train, on='No', how='left')

print("✅ Final merged dataset shape:", final.shape)
# Out:
# ✅ Final merged dataset shape: (25286, 55)
# ✅ Final merged dataset shape: (25286, 55)

# %%
final
# Out:
#        X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# 0                  198.0              0.025                   6.25
# 1                  198.0              0.000                   0.00
# 2                  198.0              0.000                   0.00
# 3                  198.0              0.025                   6.25
# 4                  198.0             -0.025                  -6.25
# ...                  ...                ...                    ...
# 25281              151.0              0.025                   6.25
# 25282              150.0            -11.800                  12.50
# 25283              149.0            -11.900                  68.70
# 25284              148.0            -12.100                 -37.50
# 25285              147.0            -11.900                  68.70
#
#        X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# 0                   198.0                 0.0                     0.0
# 1                   198.0                 0.0                     0.0
# 2                   198.0                 0.0                     0.0
# 3                   198.0                 0.0                     0.0
# 4                   198.0                 0.0                     0.0
# ...                   ...                 ...                     ...
# 25281               151.0                 0.0                     0.0
# 25282               150.0               -12.0                     0.0
# 25283               149.0               -12.0                     0.0
# 25284               148.0               -12.0                     0.0
# 25285               146.0               -12.0                     0.0
#
#        X1_CurrentFeedback  X1_DCBusVoltage  X1_OutputCurrent  \
# 0                  -1.420           0.0219             328.0
# 1                  -1.900           0.0206             329.0
# 2                  -2.060           0.0237             329.0
# 3                  -2.220           0.0225             329.0
# 4                   0.499           0.0260             329.0
# ...                   ...              ...               ...
# 25281               0.108           0.0215             324.0
# 25282              -5.450           0.1200             324.0
# 25283              -5.080           0.0881             324.0
# 25284              -3.750           0.1030             324.0
# 25285              -6.840           0.1170             324.0
#
#        X1_OutputVoltage  ...  M1_sequence_number  M1_CURRENT_FEEDRATE  \
# 0                 0.557  ...                 2.0                 50.0
# 1                 1.920  ...                 0.0                 50.0
# 2                 1.810  ...                 0.0                 50.0
# 3                 1.870  ...                 0.0                 50.0
# 4                 1.790  ...                 0.0                 50.0
# ...                 ...  ...                 ...                  ...
# 25281             2.710  ...                96.0                 12.0
# 25282            22.300  ...                96.0                 12.0
# 25283            24.400  ...                96.0                 12.0
# 25284            22.400  ...                96.0                 12.0
# 25285            23.400  ...                96.0                 12.0
#
#        Machining_Process  No  material  feedrate  clamp_pressure  \
# 0                   Prep   1       wax         6             4.0
# 1                   Prep   1       wax         6             4.0
# 2                   Prep   1       wax         6             4.0
# 3                   Prep   1       wax         6             4.0
# 4                   Prep   1       wax         6             4.0
# ...                  ...  ..       ...       ...             ...
# 25281                End  18       wax         3             2.5
# 25282                End  18       wax         3             2.5
# 25283                End  18       wax         3             2.5
# 25284                End  18       wax         3             2.5
# 25285                End  18       wax         3             2.5
#
#        tool_condition  machining_finalized  passed_visual_inspection
# 0              unworn                  yes                       yes
# 1              unworn                  yes                       yes
# 2              unworn                  yes                       yes
# 3              unworn                  yes                       yes
# 4              unworn                  yes                       yes
# ...               ...                  ...                       ...
# 25281            worn                  yes                       yes
# 25282            worn                  yes                       yes
# 25283            worn                  yes                       yes
# 25284            worn                  yes                       yes
# 25285            worn                  yes                       yes
#
# [25286 rows x 55 columns]

# %%
final.to_csv('final.csv')

# %%
df= pd.read_csv('final.csv')
df
# Out:
#        Unnamed: 0  X1_ActualPosition  X1_ActualVelocity  \
# 0               0              198.0              0.025
# 1               1              198.0              0.000
# 2               2              198.0              0.000
# 3               3              198.0              0.025
# 4               4              198.0             -0.025
# ...           ...                ...                ...
# 25281       25281              151.0              0.025
# 25282       25282              150.0            -11.800
# 25283       25283              149.0            -11.900
# 25284       25284              148.0            -12.100
# 25285       25285              147.0            -11.900
#
#        X1_ActualAcceleration  X1_CommandPosition  X1_CommandVelocity  \
# 0                       6.25               198.0                 0.0
# 1                       0.00               198.0                 0.0
# 2                       0.00               198.0                 0.0
# 3                       6.25               198.0                 0.0
# 4                      -6.25               198.0                 0.0
# ...                      ...                 ...                 ...
# 25281                   6.25               151.0                 0.0
# 25282                  12.50               150.0               -12.0
# 25283                  68.70               149.0               -12.0
# 25284                 -37.50               148.0               -12.0
# 25285                  68.70               146.0               -12.0
#
#        X1_CommandAcceleration  X1_CurrentFeedback  X1_DCBusVoltage  \
# 0                         0.0              -1.420           0.0219
# 1                         0.0              -1.900           0.0206
# 2                         0.0              -2.060           0.0237
# 3                         0.0              -2.220           0.0225
# 4                         0.0               0.499           0.0260
# ...                       ...                 ...              ...
# 25281                     0.0               0.108           0.0215
# 25282                     0.0              -5.450           0.1200
# 25283                     0.0              -5.080           0.0881
# 25284                     0.0              -3.750           0.1030
# 25285                     0.0              -6.840           0.1170
#
#        X1_OutputCurrent  ...  M1_sequence_number  M1_CURRENT_FEEDRATE  \
# 0                 328.0  ...                 2.0                 50.0
# 1                 329.0  ...                 0.0                 50.0
# 2                 329.0  ...                 0.0                 50.0
# 3                 329.0  ...                 0.0                 50.0
# 4                 329.0  ...                 0.0                 50.0
# ...                 ...  ...                 ...                  ...
# 25281             324.0  ...                96.0                 12.0
# 25282             324.0  ...                96.0                 12.0
# 25283             324.0  ...                96.0                 12.0
# 25284             324.0  ...                96.0                 12.0
# 25285             324.0  ...                96.0                 12.0
#
#        Machining_Process  No  material  feedrate  clamp_pressure  \
# 0                   Prep   1       wax         6             4.0
# 1                   Prep   1       wax         6             4.0
# 2                   Prep   1       wax         6             4.0
# 3                   Prep   1       wax         6             4.0
# 4                   Prep   1       wax         6             4.0
# ...                  ...  ..       ...       ...             ...
# 25281                End  18       wax         3             2.5
# 25282                End  18       wax         3             2.5
# 25283                End  18       wax         3             2.5
# 25284                End  18       wax         3             2.5
# 25285                End  18       wax         3             2.5
#
#        tool_condition  machining_finalized  passed_visual_inspection
# 0              unworn                  yes                       yes
# 1              unworn                  yes                       yes
# 2              unworn                  yes                       yes
# 3              unworn                  yes                       yes
# 4              unworn                  yes                       yes
# ...               ...                  ...                       ...
# 25281            worn                  yes                       yes
# 25282            worn                  yes                       yes
# 25283            worn                  yes                       yes
# 25284            worn                  yes                       yes
# 25285            worn                  yes                       yes
#
# [25286 rows x 56 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25286 entries, 0 to 25285
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   X1_ActualPosition          25286 non-null  float64
#  1   X1_ActualVelocity          25286 non-null  float64
#  2   X1_ActualAcceleration      25286 non-null  float64
#  3   X1_CommandPosition         25286 non-null  float64
#  4   X1_CommandVelocity         25286 non-null  float64
#  5   X1_CommandAcceleration     25286 non-null  float64
#  6   X1_CurrentFeedback         25286 non-null  float64
#  7   X1_DCBusVoltage            25286 non-null  float64
#  8   X1_OutputCurrent           25286 non-null  float64
#  9   X1_OutputVoltage           25286 non-null  float64
#  10  X1_OutputPower             25286 non-null  float64
#  11  Y1_ActualPosition          25286 non-null  float64
#  12  Y1_ActualVelocity          25286 non-null  float64
#  13  Y1_ActualAcceleration      25286 non-null  float64
#  14  Y1_CommandPosition         25286 non-null  float64
#  15  Y1_CommandVelocity         25286 non-null  float64
#  16  Y1_CommandAcceleration     25286 non-null  float64
#  17  Y1_CurrentFeedback         25286 non-null  float64
#  18  Y1_DCBusVoltage            25286 non-null  float64
#  19  Y1_OutputCurrent           25286 non-null  float64
#  20  Y1_OutputVoltage           25286 non-null  float64
#  21  Y1_OutputPower             25286 non-null  float64
#  22  Z1_ActualPosition          25286 non-null  float64
#  23  Z1_ActualVelocity          25286 non-null  float64
#  24  Z1_ActualAcceleration      25286 non-null  float64
#  25  Z1_CommandPosition         25286 non-null  float64
#  26  Z1_CommandVelocity         25286 non-null  float64
#  27  Z1_CommandAcceleration     25286 non-null  float64
#  28  Z1_CurrentFeedback         25286 non-null  float64
#  29  Z1_DCBusVoltage            25286 non-null  float64
#  30  Z1_OutputCurrent           25286 non-null  float64
#  31  Z1_OutputVoltage           25286 non-null  float64
#  32  S1_ActualPosition          25286 non-null  float64
#  33  S1_ActualVelocity          25286 non-null  float64
#  34  S1_ActualAcceleration      25286 non-null  float64
#  35  S1_CommandPosition         25286 non-null  float64
#  36  S1_CommandVelocity         25286 non-null  float64
#  37  S1_CommandAcceleration     25286 non-null  float64
#  38  S1_CurrentFeedback         25286 non-null  float64
#  39  S1_DCBusVoltage            25286 non-null  float64
#  40  S1_OutputCurrent           25286 non-null  float64
#  41  S1_OutputVoltage           25286 non-null  float64
#  42  S1_OutputPower             25286 non-null  float64
#  43  S1_SystemInertia           25286 non-null  float64
#  44  M1_CURRENT_PROGRAM_NUMBER  25286 non-null  float64
#  45  M1_sequence_number         25286 non-null  float64
#  46  M1_CURRENT_FEEDRATE        25286 non-null  float64
#  47  Machining_Process          25286 non-null  object
#  48  No                         25286 non-null  int64
#  49  material                   25286 non-null  object
#  50  feedrate                   25286 non-null  int64
#  51  clamp_pressure             25286 non-null  float64
#  52  tool_condition             25286 non-null  object
#  53  machining_finalized        25286 non-null  object
#  54  passed_visual_inspection   25286 non-null  object
# dtypes: float64(48), int64(2), object(5)
# memory usage: 10.6+ MB

# %%
df
# Out:
#        X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# 0                  198.0              0.025                   6.25
# 1                  198.0              0.000                   0.00
# 2                  198.0              0.000                   0.00
# 3                  198.0              0.025                   6.25
# 4                  198.0             -0.025                  -6.25
# ...                  ...                ...                    ...
# 25281              151.0              0.025                   6.25
# 25282              150.0            -11.800                  12.50
# 25283              149.0            -11.900                  68.70
# 25284              148.0            -12.100                 -37.50
# 25285              147.0            -11.900                  68.70
#
#        X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# 0                   198.0                 0.0                     0.0
# 1                   198.0                 0.0                     0.0
# 2                   198.0                 0.0                     0.0
# 3                   198.0                 0.0                     0.0
# 4                   198.0                 0.0                     0.0
# ...                   ...                 ...                     ...
# 25281               151.0                 0.0                     0.0
# 25282               150.0               -12.0                     0.0
# 25283               149.0               -12.0                     0.0
# 25284               148.0               -12.0                     0.0
# 25285               146.0               -12.0                     0.0
#
#        X1_CurrentFeedback  X1_DCBusVoltage  X1_OutputCurrent  \
# 0                  -1.420           0.0219             328.0
# 1                  -1.900           0.0206             329.0
# 2                  -2.060           0.0237             329.0
# 3                  -2.220           0.0225             329.0
# 4                   0.499           0.0260             329.0
# ...                   ...              ...               ...
# 25281               0.108           0.0215             324.0
# 25282              -5.450           0.1200             324.0
# 25283              -5.080           0.0881             324.0
# 25284              -3.750           0.1030             324.0
# 25285              -6.840           0.1170             324.0
#
#        X1_OutputVoltage  ...  S1_SystemInertia  M1_CURRENT_PROGRAM_NUMBER  \
# 0                 0.557  ...              12.0                        1.0
# 1                 1.920  ...              12.0                        1.0
# 2                 1.810  ...              12.0                        1.0
# 3                 1.870  ...              12.0                        1.0
# 4                 1.790  ...              12.0                        1.0
# ...                 ...  ...               ...                        ...
# 25281             2.710  ...              12.0                        1.0
# 25282            22.300  ...              12.0                        1.0
# 25283            24.400  ...              12.0                        1.0
# 25284            22.400  ...              12.0                        1.0
# 25285            23.400  ...              12.0                        1.0
#
#        M1_sequence_number  M1_CURRENT_FEEDRATE  Machining_Process  feedrate  \
# 0                     2.0                 50.0                  7         6
# 1                     0.0                 50.0                  7         6
# 2                     0.0                 50.0                  7         6
# 3                     0.0                 50.0                  7         6
# 4                     0.0                 50.0                  7         6
# ...                   ...                  ...                ...       ...
# 25281                96.0                 12.0                  0         3
# 25282                96.0                 12.0                  0         3
# 25283                96.0                 12.0                  0         3
# 25284                96.0                 12.0                  0         3
# 25285                96.0                 12.0                  0         3
#
#        clamp_pressure  tool_condition  machining_finalized  \
# 0                 4.0          unworn                  yes
# 1                 4.0          unworn                  yes
# 2                 4.0          unworn                  yes
# 3                 4.0          unworn                  yes
# 4                 4.0          unworn                  yes
# ...               ...             ...                  ...
# 25281             2.5            worn                  yes
# 25282             2.5            worn                  yes
# 25283             2.5            worn                  yes
# 25284             2.5            worn                  yes
# 25285             2.5            worn                  yes
#
#        passed_visual_inspection
# 0                           yes
# 1                           yes
# 2                           yes
# 3                           yes
# 4                           yes
# ...                         ...
# 25281                       yes
# 25282                       yes
# 25283                       yes
# 25284                       yes
# 25285                       yes
#
# [25286 rows x 53 columns]

# %%
df.columns
# Out:
# Index(['X1_ActualPosition', 'X1_ActualVelocity', 'X1_ActualAcceleration',
#        'X1_CommandPosition', 'X1_CommandVelocity', 'X1_CommandAcceleration',
#        'X1_CurrentFeedback', 'X1_DCBusVoltage', 'X1_OutputCurrent',
#        'X1_OutputVoltage', 'X1_OutputPower', 'Y1_ActualPosition',
#        'Y1_ActualVelocity', 'Y1_ActualAcceleration', 'Y1_CommandPosition',
#        'Y1_CommandVelocity', 'Y1_CommandAcceleration', 'Y1_CurrentFeedback',
#        'Y1_DCBusVoltage', 'Y1_OutputCurrent', 'Y1_OutputVoltage',
#        'Y1_OutputPower', 'Z1_ActualPosition', 'Z1_ActualVelocity',
#        'Z1_ActualAcceleration', 'Z1_CommandPosition', 'Z1_CommandVelocity',
#        'Z1_CommandAcceleration', 'Z1_CurrentFeedback', 'Z1_DCBusVoltage',
#        'Z1_OutputCurrent', 'Z1_OutputVoltage', 'S1_ActualPosition',
#        'S1_ActualVelocity', 'S1_ActualAcceleration', 'S1_CommandPosition',
#        'S1_CommandVelocity', 'S1_CommandAcceleration', 'S1_CurrentFeedback',
#        'S1_DCBusVoltage', 'S1_OutputCurrent', 'S1_OutputVoltage',
#        'S1_OutputPower', 'S1_SystemInertia', 'M1_CURRENT_PROGRAM_NUMBER',
#        'M1_sequence_number', 'M1_CURRENT_FEEDRATE', 'Machining_Process',
#        'feedrate', 'clamp_pressure', 'tool_condition', 'machining_finalized',
#        'passed_visual_inspection'],
#       dtype='object')

# %%
category=['tool_condition', 'machining_finalized', 'passed_visual_inspection']
continuous=['X1_ActualPosition', 'X1_ActualVelocity', 'X1_ActualAcceleration',
       'X1_CommandPosition', 'X1_CommandVelocity', 'X1_CommandAcceleration',
       'X1_CurrentFeedback', 'X1_DCBusVoltage', 'X1_OutputCurrent',
       'X1_OutputVoltage', 'X1_OutputPower', 'Y1_ActualPosition',
       'Y1_ActualVelocity', 'Y1_ActualAcceleration', 'Y1_CommandPosition',
       'Y1_CommandVelocity', 'Y1_CommandAcceleration', 'Y1_CurrentFeedback',
       'Y1_DCBusVoltage', 'Y1_OutputCurrent', 'Y1_OutputVoltage',
       'Y1_OutputPower', 'Z1_ActualPosition', 'Z1_ActualVelocity',
       'Z1_ActualAcceleration', 'Z1_CommandPosition', 'Z1_CommandVelocity',
       'Z1_CommandAcceleration', 'Z1_CurrentFeedback', 'Z1_DCBusVoltage',
       'Z1_OutputCurrent', 'Z1_OutputVoltage', 'S1_ActualPosition',
       'S1_ActualVelocity', 'S1_ActualAcceleration', 'S1_CommandPosition',
       'S1_CommandVelocity', 'S1_CommandAcceleration', 'S1_CurrentFeedback',
       'S1_DCBusVoltage', 'S1_OutputCurrent', 'S1_OutputVoltage',
       'S1_OutputPower', 'S1_SystemInertia', 'M1_CURRENT_PROGRAM_NUMBER',
       'M1_sequence_number', 'M1_CURRENT_FEEDRATE', 'Machining_Process']

# %%
import pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Load the dataset
data = pd.read_csv('/content/final.csv')

# Drop unnecessary columns safely
data = data.drop(columns=['Unnamed: 0'], errors='ignore')

# Label Encoding for categorical variables
label_encoders = {}
categorical_columns = ['tool_condition', 'machining_finalized', 'passed_visual_inspection']

for column in categorical_columns:
    le = LabelEncoder()
    data[column] = le.fit_transform(data[column])
    label_encoders[column] = le

    # Save each label encoder separately
    with open(f'label_encoder_{column}.pkl', 'wb') as file:
        pickle.dump(le, file)

print("Label encoders saved successfully!")

# Identify and drop non-numeric columns (if necessary)
non_numeric_columns = data.select_dtypes(include=['object']).columns
data = data.drop(columns=non_numeric_columns)

# Separate features and labels
X = data.drop(columns=categorical_columns)
y = data[categorical_columns]

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Save the scaler
with open('scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)

print("Scaler saved successfully!")

# Reshape data for LSTM (samples, timesteps, features)
X_reshaped = X_scaled.reshape((X_scaled.shape[0], 1, X_scaled.shape[1]))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y, test_size=0.2, random_state=42, stratify=y)

print("Data preprocessing completed successfully!")
# Out:
# Label encoders saved successfully!
# Scaler saved successfully!
# Data preprocessing completed successfully!

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, concatenate

# Define the input shape
input_shape = (X_train.shape[1], X_train.shape[2])

# Define the input layer
inputs = Input(shape=input_shape)

# Add LSTM layers
lstm1 = LSTM(50, return_sequences=True)(inputs)
dropout1 = Dropout(0.2)(lstm1)
lstm2 = LSTM(50, return_sequences=False)(dropout1)
dropout2 = Dropout(0.2)(lstm2)

# Add Dense layers for multi-output classification
dense = Dense(50, activation='relu')(dropout2)

# Define separate output layers for each target
output1 = Dense(len(label_encoders['tool_condition'].classes_), activation='softmax', name='tool_condition')(dense)
output2 = Dense(len(label_encoders['machining_finalized'].classes_), activation='softmax', name='machining_finalized')(dense)
output3 = Dense(len(label_encoders['passed_visual_inspection'].classes_), activation='softmax', name='passed_visual_inspection')(dense)

# Define the model
model = Model(inputs=inputs, outputs=[output1, output2, output3])

# %%
model.compile(optimizer='adam',
              loss={
                  'tool_condition': 'sparse_categorical_crossentropy',
                  'machining_finalized': 'sparse_categorical_crossentropy',
                  'passed_visual_inspection': 'sparse_categorical_crossentropy'
              },
              metrics={
                  'tool_condition': ['accuracy'],
                  'machining_finalized': ['accuracy'],
                  'passed_visual_inspection': ['accuracy']
              })

# Split y_train and y_test into separate arrays for each target
y_train_tool = y_train['tool_condition']
y_train_machining = y_train['machining_finalized']
y_train_inspection = y_train['passed_visual_inspection']

y_test_tool = y_test['tool_condition']
y_test_machining = y_test['machining_finalized']
y_test_inspection = y_test['passed_visual_inspection']




# Train the model
history = model.fit(X_train,
                    {'tool_condition': y_train_tool,
                     'machining_finalized': y_train_machining,
                     'passed_visual_inspection': y_train_inspection},
                    epochs=20,
                    batch_size=32,
                    validation_data=(X_test,
                                    {'tool_condition': y_test_tool,
                                     'machining_finalized': y_test_machining,
                                     'passed_visual_inspection': y_test_inspection}),
                    verbose=1)
# Out:
# Epoch 1/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 1.0561 - machining_finalized_accuracy: 0.8705 - machining_finalized_loss: 0.3277 - passed_visual_inspection_accuracy: 0.8198 - passed_visual_inspection_loss: 0.3390 - tool_condition_accuracy: 0.8083 - tool_condition_loss: 0.3894 - val_loss: 0.1191 - val_machining_finalized_accuracy: 0.9921 - val_machining_finalized_loss: 0.0250 - val_passed_visual_inspection_accuracy: 0.9921 - val_passed_visual_inspection_loss: 0.0213 - val_tool_condition_accuracy: 0.9723 - val_tool_condition_loss: 0.0723
# Epoch 2/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.1339 - machining_finalized_accuracy: 0.9895 - machining_finalized_loss: 0.0285 - passed_visual_inspection_accuracy: 0.9917 - passed_visual_inspection_loss: 0.0263 - tool_condition_accuracy: 0.9706 - tool_condition_loss: 0.0791 - val_loss: 0.0672 - val_machining_finalized_accuracy: 0.9943 - val_machining_finalized_loss: 0.0132 - val_passed_visual_inspection_accuracy: 0.9939 - val_passed_visual_inspection_loss: 0.0133 - val_tool_condition_accuracy: 0.9864 - val_tool_condition_loss: 0.0404
# Epoch 3/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0831 - machining_finalized_accuracy: 0.9943 - machining_finalized_loss: 0.0170 - passed_visual_inspection_accuracy: 0.9940 - passed_visual_inspection_loss: 0.0163 - tool_condition_accuracy: 0.9829 - tool_condition_loss: 0.0499 - val_loss: 0.0371 - val_machining_finalized_accuracy: 0.9982 - val_machining_finalized_loss: 0.0078 - val_passed_visual_inspection_accuracy: 0.9990 - val_passed_visual_inspection_loss: 0.0051 - val_tool_condition_accuracy: 0.9923 - val_tool_condition_loss: 0.0240
# Epoch 4/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0523 - machining_finalized_accuracy: 0.9968 - machining_finalized_loss: 0.0126 - passed_visual_inspection_accuracy: 0.9973 - passed_visual_inspection_loss: 0.0080 - tool_condition_accuracy: 0.9896 - tool_condition_loss: 0.0317 - val_loss: 0.0302 - val_machining_finalized_accuracy: 0.9982 - val_machining_finalized_loss: 0.0061 - val_passed_visual_inspection_accuracy: 0.9984 - val_passed_visual_inspection_loss: 0.0043 - val_tool_condition_accuracy: 0.9949 - val_tool_condition_loss: 0.0196
# Epoch 5/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0400 - machining_finalized_accuracy: 0.9970 - machining_finalized_loss: 0.0099 - passed_visual_inspection_accuracy: 0.9977 - passed_visual_inspection_loss: 0.0070 - tool_condition_accuracy: 0.9921 - tool_condition_loss: 0.0231 - val_loss: 0.0213 - val_machining_finalized_accuracy: 0.9982 - val_machining_finalized_loss: 0.0050 - val_passed_visual_inspection_accuracy: 0.9990 - val_passed_visual_inspection_loss: 0.0040 - val_tool_condition_accuracy: 0.9953 - val_tool_condition_loss: 0.0122
# Epoch 6/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0311 - machining_finalized_accuracy: 0.9977 - machining_finalized_loss: 0.0083 - passed_visual_inspection_accuracy: 0.9985 - passed_visual_inspection_loss: 0.0041 - tool_condition_accuracy: 0.9931 - tool_condition_loss: 0.0187 - val_loss: 0.0155 - val_machining_finalized_accuracy: 0.9994 - val_machining_finalized_loss: 0.0027 - val_passed_visual_inspection_accuracy: 0.9996 - val_passed_visual_inspection_loss: 0.0013 - val_tool_condition_accuracy: 0.9960 - val_tool_condition_loss: 0.0114
# Epoch 7/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0281 - machining_finalized_accuracy: 0.9980 - machining_finalized_loss: 0.0066 - passed_visual_inspection_accuracy: 0.9979 - passed_visual_inspection_loss: 0.0051 - tool_condition_accuracy: 0.9938 - tool_condition_loss: 0.0164 - val_loss: 0.0115 - val_machining_finalized_accuracy: 0.9988 - val_machining_finalized_loss: 0.0030 - val_passed_visual_inspection_accuracy: 0.9996 - val_passed_visual_inspection_loss: 0.0011 - val_tool_condition_accuracy: 0.9972 - val_tool_condition_loss: 0.0074
# Epoch 8/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0193 - machining_finalized_accuracy: 0.9987 - machining_finalized_loss: 0.0049 - passed_visual_inspection_accuracy: 0.9990 - passed_visual_inspection_loss: 0.0032 - tool_condition_accuracy: 0.9963 - tool_condition_loss: 0.0113 - val_loss: 0.0145 - val_machining_finalized_accuracy: 0.9978 - val_machining_finalized_loss: 0.0046 - val_passed_visual_inspection_accuracy: 0.9990 - val_passed_visual_inspection_loss: 0.0024 - val_tool_condition_accuracy: 0.9988 - val_tool_condition_loss: 0.0074
# Epoch 9/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0217 - machining_finalized_accuracy: 0.9986 - machining_finalized_loss: 0.0046 - passed_visual_inspection_accuracy: 0.9985 - passed_visual_inspection_loss: 0.0036 - tool_condition_accuracy: 0.9958 - tool_condition_loss: 0.0136 - val_loss: 0.0100 - val_machining_finalized_accuracy: 0.9986 - val_machining_finalized_loss: 0.0033 - val_passed_visual_inspection_accuracy: 0.9998 - val_passed_visual_inspection_loss: 6.5176e-04 - val_tool_condition_accuracy: 0.9980 - val_tool_condition_loss: 0.0061
# Epoch 10/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0194 - machining_finalized_accuracy: 0.9982 - machining_finalized_loss: 0.0057 - passed_visual_inspection_accuracy: 0.9991 - passed_visual_inspection_loss: 0.0026 - tool_condition_accuracy: 0.9960 - tool_condition_loss: 0.0110 - val_loss: 0.0141 - val_machining_finalized_accuracy: 0.9984 - val_machining_finalized_loss: 0.0035 - val_passed_visual_inspection_accuracy: 0.9992 - val_passed_visual_inspection_loss: 0.0023 - val_tool_condition_accuracy: 0.9976 - val_tool_condition_loss: 0.0082
# Epoch 11/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0150 - machining_finalized_accuracy: 0.9985 - machining_finalized_loss: 0.0039 - passed_visual_inspection_accuracy: 0.9991 - passed_visual_inspection_loss: 0.0025 - tool_condition_accuracy: 0.9970 - tool_condition_loss: 0.0087 - val_loss: 0.0131 - val_machining_finalized_accuracy: 0.9990 - val_machining_finalized_loss: 0.0025 - val_passed_visual_inspection_accuracy: 0.9996 - val_passed_visual_inspection_loss: 0.0010 - val_tool_condition_accuracy: 0.9972 - val_tool_condition_loss: 0.0095
# Epoch 12/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0144 - machining_finalized_accuracy: 0.9992 - machining_finalized_loss: 0.0029 - passed_visual_inspection_accuracy: 0.9996 - passed_visual_inspection_loss: 0.0014 - tool_condition_accuracy: 0.9967 - tool_condition_loss: 0.0101 - val_loss: 0.0108 - val_machining_finalized_accuracy: 0.9988 - val_machining_finalized_loss: 0.0027 - val_passed_visual_inspection_accuracy: 0.9996 - val_passed_visual_inspection_loss: 0.0013 - val_tool_condition_accuracy: 0.9982 - val_tool_condition_loss: 0.0068
# Epoch 13/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0145 - machining_finalized_accuracy: 0.9987 - machining_finalized_loss: 0.0038 - passed_visual_inspection_accuracy: 0.9995 - passed_visual_inspection_loss: 0.0018 - tool_condition_accuracy: 0.9970 - tool_condition_loss: 0.0089 - val_loss: 0.0111 - val_machining_finalized_accuracy: 0.9988 - val_machining_finalized_loss: 0.0037 - val_passed_visual_inspection_accuracy: 0.9996 - val_passed_visual_inspection_loss: 0.0016 - val_tool_condition_accuracy: 0.9984 - val_tool_condition_loss: 0.0057
# Epoch 14/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0126 - machining_finalized_accuracy: 0.9984 - machining_finalized_loss: 0.0044 - passed_visual_inspection_accuracy: 0.9996 - passed_visual_inspection_loss: 0.0017 - tool_condition_accuracy: 0.9981 - tool_condition_loss: 0.0065 - val_loss: 0.0138 - val_machining_finalized_accuracy: 0.9990 - val_machining_finalized_loss: 0.0037 - val_passed_visual_inspection_accuracy: 0.9996 - val_passed_visual_inspection_loss: 0.0011 - val_tool_condition_accuracy: 0.9970 - val_tool_condition_loss: 0.0089
# Epoch 15/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0106 - machining_finalized_accuracy: 0.9995 - machining_finalized_loss: 0.0022 - passed_visual_inspection_accuracy: 0.9997 - passed_visual_inspection_loss: 0.0014 - tool_condition_accuracy: 0.9975 - tool_condition_loss: 0.0070 - val_loss: 0.0071 - val_machining_finalized_accuracy: 0.9996 - val_machining_finalized_loss: 0.0013 - val_passed_visual_inspection_accuracy: 1.0000 - val_passed_visual_inspection_loss: 1.9312e-04 - val_tool_condition_accuracy: 0.9984 - val_tool_condition_loss: 0.0055
# Epoch 16/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0187 - machining_finalized_accuracy: 0.9986 - machining_finalized_loss: 0.0041 - passed_visual_inspection_accuracy: 0.9995 - passed_visual_inspection_loss: 0.0021 - tool_condition_accuracy: 0.9962 - tool_condition_loss: 0.0125 - val_loss: 0.0081 - val_machining_finalized_accuracy: 0.9988 - val_machining_finalized_loss: 0.0025 - val_passed_visual_inspection_accuracy: 0.9998 - val_passed_visual_inspection_loss: 0.0012 - val_tool_condition_accuracy: 0.9980 - val_tool_condition_loss: 0.0044
# Epoch 17/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0100 - machining_finalized_accuracy: 0.9991 - machining_finalized_loss: 0.0023 - passed_visual_inspection_accuracy: 0.9996 - passed_visual_inspection_loss: 0.0017 - tool_condition_accuracy: 0.9975 - tool_condition_loss: 0.0061 - val_loss: 0.0070 - val_machining_finalized_accuracy: 0.9994 - val_machining_finalized_loss: 0.0015 - val_passed_visual_inspection_accuracy: 0.9998 - val_passed_visual_inspection_loss: 0.0013 - val_tool_condition_accuracy: 0.9986 - val_tool_condition_loss: 0.0042
# Epoch 18/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0109 - machining_finalized_accuracy: 0.9996 - machining_finalized_loss: 0.0015 - passed_visual_inspection_accuracy: 0.9996 - passed_visual_inspection_loss: 0.0014 - tool_condition_accuracy: 0.9968 - tool_condition_loss: 0.0079 - val_loss: 0.0112 - val_machining_finalized_accuracy: 0.9988 - val_machining_finalized_loss: 0.0030 - val_passed_visual_inspection_accuracy: 0.9996 - val_passed_visual_inspection_loss: 5.2041e-04 - val_tool_condition_accuracy: 0.9972 - val_tool_condition_loss: 0.0075
# Epoch 19/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0098 - machining_finalized_accuracy: 0.9992 - machining_finalized_loss: 0.0033 - passed_visual_inspection_accuracy: 0.9997 - passed_visual_inspection_loss: 0.0012 - tool_condition_accuracy: 0.9980 - tool_condition_loss: 0.0052 - val_loss: 0.0088 - val_machining_finalized_accuracy: 0.9994 - val_machining_finalized_loss: 0.0023 - val_passed_visual_inspection_accuracy: 0.9994 - val_passed_visual_inspection_loss: 0.0022 - val_tool_condition_accuracy: 0.9990 - val_tool_condition_loss: 0.0043
# Epoch 20/20
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0108 - machining_finalized_accuracy: 0.9984 - machining_finalized_loss: 0.0041 - passed_visual_inspection_accuracy: 0.9996 - passed_visual_inspection_loss: 0.0014 - tool_condition_accuracy: 0.9982 - tool_condition_loss: 0.0052 - val_loss: 0.0057 - val_machining_finalized_accuracy: 0.9990 - val_machining_finalized_loss: 0.0022 - val_passed_visual_inspection_accuracy: 1.0000 - val_passed_visual_inspection_loss: 1.4626e-04 - val_tool_condition_accuracy: 0.9992 - val_tool_condition_loss: 0.0033

# %%
# Define the file path to save the model
model_save_path = "trained_model.h5"

# Save the trained model
model.save(model_save_path)

# Download the model file
from google.colab import files  # If using Google Colab
files.download(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
